# %%
# !pip install pandas-datareader

# %%
pip install --upgrade pandas-datareader

# %%
import pandas_datareader as pdr

# %%
key="c04ac447386b51390606abc0f0197aac7c23fdfa"

# %%
df=pdr.get_data_tiingo('AAPL', api_key=key)
# Out:
# <ipython-input-12-2e11dfbe243e>:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df=pdr.get_data_tiingo('AAPL', api_key=key)

# %%
df.head()
# Out:
#                                    close    high     low    open    volume  \
# symbol date
# AAPL   2019-01-07 00:00:00+00:00  147.93  148.83  145.90  148.70  54777764
#        2019-01-08 00:00:00+00:00  150.75  151.82  148.52  149.56  41025314
#        2019-01-09 00:00:00+00:00  153.31  154.53  149.63  151.29  45099081
#        2019-01-10 00:00:00+00:00  153.80  153.97  150.86  152.50  35780670
#        2019-01-11 00:00:00+00:00  152.29  153.70  151.51  152.88  27023241
#
#                                    adjClose    adjHigh     adjLow    adjOpen  \
# symbol date
# AAPL   2019-01-07 00:00:00+00:00  35.495091  35.711042  35.008003  35.679849
#        2019-01-08 00:00:00+00:00  36.171737  36.428478  35.636659  35.886202
#        2019-01-09 00:00:00+00:00  36.785996  37.078729  35.902998  36.301307
#        2019-01-10 00:00:00+00:00  36.903569  36.944360  36.198131  36.591641
#        2019-01-11 00:00:00+00:00  36.541252  36.879575  36.354095  36.682820
#
# ...

# %%
df.tail()
# Out:
#                                    close      high      low    open    volume  \
# symbol date
# AAPL   2023-12-29 00:00:00+00:00  192.53  194.4000  191.725  193.90  42672148
#        2024-01-02 00:00:00+00:00  185.64  188.4400  183.885  187.15  82488674
#        2024-01-03 00:00:00+00:00  184.25  185.8800  183.430  184.22  58414460
#        2024-01-04 00:00:00+00:00  181.91  183.0872  180.880  182.15  71983570
#        2024-01-05 00:00:00+00:00  181.18  182.7600  180.170  181.99  62196924
#
#                                   adjClose   adjHigh   adjLow  adjOpen  \
# symbol date
# AAPL   2023-12-29 00:00:00+00:00    192.53  194.4000  191.725   193.90
#        2024-01-02 00:00:00+00:00    185.64  188.4400  183.885   187.15
#        2024-01-03 00:00:00+00:00    184.25  185.8800  183.430   184.22
#        2024-01-04 00:00:00+00:00    181.91  183.0872  180.880   182.15
#        2024-01-05 00:00:00+00:00    181.18  182.7600  180.170   181.99
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1259 entries, ('AAPL', Timestamp('2019-01-07 00:00:00+0000', tz='UTC')) to ('AAPL', Timestamp('2024-01-05 00:00:00+0000', tz='UTC'))
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   close        1259 non-null   float64
#  1   high         1259 non-null   float64
#  2   low          1259 non-null   float64
#  3   open         1259 non-null   float64
#  4   volume       1259 non-null   int64
#  5   adjClose     1259 non-null   float64
#  6   adjHigh      1259 non-null   float64
#  7   adjLow       1259 non-null   float64
#  8   adjOpen      1259 non-null   float64
#  9   adjVolume    1259 non-null   int64
#  10  divCash      1259 non-null   float64
#  11  splitFactor  1259 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 164.1+ KB

# %%
df.to_csv('AAPL_share_price.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1259 entries, ('AAPL', Timestamp('2019-01-07 00:00:00+0000', tz='UTC')) to ('AAPL', Timestamp('2024-01-05 00:00:00+0000', tz='UTC'))
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   close        1259 non-null   float64
#  1   high         1259 non-null   float64
#  2   low          1259 non-null   float64
#  3   open         1259 non-null   float64
#  4   volume       1259 non-null   int64
#  5   adjClose     1259 non-null   float64
#  6   adjHigh      1259 non-null   float64
#  7   adjLow       1259 non-null   float64
#  8   adjOpen      1259 non-null   float64
#  9   adjVolume    1259 non-null   int64
#  10  divCash      1259 non-null   float64
#  11  splitFactor  1259 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 164.1+ KB

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd
dataset=pd.read_csv('AAPL_share_price.csv')

# %%
dataset.head()
# Out:
#   symbol                       date   close    high     low    open    volume  \
# 0   AAPL  2019-01-07 00:00:00+00:00  147.93  148.83  145.90  148.70  54777764
# 1   AAPL  2019-01-08 00:00:00+00:00  150.75  151.82  148.52  149.56  41025314
# 2   AAPL  2019-01-09 00:00:00+00:00  153.31  154.53  149.63  151.29  45099081
# 3   AAPL  2019-01-10 00:00:00+00:00  153.80  153.97  150.86  152.50  35780670
# 4   AAPL  2019-01-11 00:00:00+00:00  152.29  153.70  151.51  152.88  27023241
#
#     adjClose    adjHigh     adjLow    adjOpen  adjVolume  divCash  splitFactor
# 0  35.495091  35.711042  35.008003  35.679849  219111056      0.0          1.0
# 1  36.171737  36.428478  35.636659  35.886202  164101256      0.0          1.0
# 2  36.785996  37.078729  35.902998  36.301307  180396324      0.0          1.0
# 3  36.903569  36.944360  36.198131  36.591641  143122680      0.0          1.0
# 4  36.541252  36.879575  36.354095  36.682820  108092964      0.0          1.0

# %%
dataset=dataset.iloc[:,1:7]

# %%
dataset.head()
# Out:
#                         date   close    high     low    open    volume
# 0  2019-01-07 00:00:00+00:00  147.93  148.83  145.90  148.70  54777764
# 1  2019-01-08 00:00:00+00:00  150.75  151.82  148.52  149.56  41025314
# 2  2019-01-09 00:00:00+00:00  153.31  154.53  149.63  151.29  45099081
# 3  2019-01-10 00:00:00+00:00  153.80  153.97  150.86  152.50  35780670
# 4  2019-01-11 00:00:00+00:00  152.29  153.70  151.51  152.88  27023241

# %%
# working with dates

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   object
#  1   close   1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   open    1259 non-null   float64
#  5   volume  1259 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 59.1+ KB

# %%
dataset['date']=pd.to_datetime(dataset['date'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   datetime64[ns, UTC]
#  1   close   1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   open    1259 non-null   float64
#  5   volume  1259 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(1)
# memory usage: 59.1 KB

# %%
dataset.head()
# Out:
#                        date   close    high     low    open    volume
# 0 2019-01-07 00:00:00+00:00  147.93  148.83  145.90  148.70  54777764
# 1 2019-01-08 00:00:00+00:00  150.75  151.82  148.52  149.56  41025314
# 2 2019-01-09 00:00:00+00:00  153.31  154.53  149.63  151.29  45099081
# 3 2019-01-10 00:00:00+00:00  153.80  153.97  150.86  152.50  35780670
# 4 2019-01-11 00:00:00+00:00  152.29  153.70  151.51  152.88  27023241

# %%
import datetime

# %%
dataset['date1']= dataset['date'].dt.date

# %%
dataset=dataset[['date1','close',	'high',	'low' ,'open','volume']]

# %%
dataset.head()
# Out:
#         date1   close    high     low    open    volume
# 0  2019-01-07  147.93  148.83  145.90  148.70  54777764
# 1  2019-01-08  150.75  151.82  148.52  149.56  41025314
# 2  2019-01-09  153.31  154.53  149.63  151.29  45099081
# 3  2019-01-10  153.80  153.97  150.86  152.50  35780670
# 4  2019-01-11  152.29  153.70  151.51  152.88  27023241

# %%
from pandas.tseries.offsets import BDay

# %%
date2=pd.date_range(start='2018-10-08', end='2023-10-04', freq=BDay())

# %%
date2
# Out:
# DatetimeIndex(['2018-10-08', '2018-10-09', '2018-10-10', '2018-10-11',
#                '2018-10-12', '2018-10-15', '2018-10-16', '2018-10-17',
#                '2018-10-18', '2018-10-19',
#                ...
#                '2023-09-21', '2023-09-22', '2023-09-25', '2023-09-26',
#                '2023-09-27', '2023-09-28', '2023-09-29', '2023-10-02',
#                '2023-10-03', '2023-10-04'],
#               dtype='datetime64[ns]', length=1303, freq='B')

# %%
len(date2)
# Out:
# 1303

# %%
len(dataset)
# Out:
# 1259

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay  # Note the corrected class name

# %%
us_bd=CustomBusinessDay(calendar=USFederalHolidayCalendar())

# %%
date3 = pd.date_range(start='2018-10-08', end='2023-10-04', freq=us_bd)
date3
# Out:
# DatetimeIndex(['2018-10-09', '2018-10-10', '2018-10-11', '2018-10-12',
#                '2018-10-15', '2018-10-16', '2018-10-17', '2018-10-18',
#                '2018-10-19', '2018-10-22',
#                ...
#                '2023-09-21', '2023-09-22', '2023-09-25', '2023-09-26',
#                '2023-09-27', '2023-09-28', '2023-09-29', '2023-10-02',
#                '2023-10-03', '2023-10-04'],
#               dtype='datetime64[ns]', length=1250, freq='C')

# %%
len(date3)
# Out:
# 1250

# %%
dataset.tail()
# Out:
#            date1   close      high      low    open    volume
# 1254  2023-12-29  192.53  194.4000  191.725  193.90  42672148
# 1255  2024-01-02  185.64  188.4400  183.885  187.15  82488674
# 1256  2024-01-03  184.25  185.8800  183.430  184.22  58414460
# 1257  2024-01-04  181.91  183.0872  180.880  182.15  71983570
# 1258  2024-01-05  181.18  182.7600  180.170  181.99  62196924

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date1   1259 non-null   object
#  1   close   1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   open    1259 non-null   float64
#  5   volume  1259 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 59.1+ KB

# %%
dataset['date1']=pd.to_datetime(dataset['date1'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date1   1259 non-null   datetime64[ns]
#  1   close   1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   open    1259 non-null   float64
#  5   volume  1259 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 59.1 KB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode()
# %matplotlib inline
import seaborn as sns
sns.set()
import datetime, time
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.figure(figsize=(15,8))
plt.plot(dataset['date1'], dataset['close'])
plt.grid()

# %%
sns.boxplot(x=dataset['date1'], y=dataset['close'])
# Out:
# <Axes: xlabel='date1', ylabel='close'>

# %%
dataset.head()
# Out:
#        date1   close    high     low    open    volume
# 0 2018-10-08  223.77  224.80  220.20  222.21  29663923
# 1 2018-10-09  226.87  227.27  222.25  223.64  26891029
# 2 2018-10-10  216.36  226.35  216.05  225.46  41990554
# 3 2018-10-11  214.45  219.50  212.32  214.52  53124392
# 4 2018-10-12  222.11  222.88  216.84  220.42  40337851

# %%
dataset.set_index('date1', inplace=True)

# %%
dataset.head()
# Out:
#              close    high     low    open    volume
# date1
# 2018-10-08  223.77  224.80  220.20  222.21  29663923
# 2018-10-09  226.87  227.27  222.25  223.64  26891029
# 2018-10-10  216.36  226.35  216.05  225.46  41990554
# 2018-10-11  214.45  219.50  212.32  214.52  53124392
# 2018-10-12  222.11  222.88  216.84  220.42  40337851

# %%
sns.boxplot(x=dataset.index.year, y=dataset['close'])
plt.grid()

# %%
#huge variance in 2020 due to covid

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=dataset.index.month_name(), y = dataset['close'])
plt.xticks(rotation=45)
plt.grid()

# %%
# september, october, november are most stable months, so if people want to remove the share then this months are preferable.
# but if people want to sale the shares then august month will be good because its contain lost of outliers so the value can get increased.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition_1=seasonal_decompose(dataset['close'], model='additive', period=12)
plt.figure(figsize=(15,8))
decomposition_1.plot()
plt.show()

# %%
trend = decomposition_1.trend
seasonality = decomposition_1.seasonal
residual = decomposition_1.resid

# %%
print("Trend :", trend.head(20))
print("****************"*10)
print("Seaonality :", seasonality.head(20))
print("****************"*10)
print("Residual :", residual.head(20))
# Out:
# Trend : date1
# 2018-10-08           NaN
# 2018-10-09           NaN
# 2018-10-10           NaN
# 2018-10-11           NaN
# 2018-10-12           NaN
# 2018-10-15           NaN
# 2018-10-16    219.885833
# 2018-10-17    219.229583
# 2018-10-18    218.932500
# 2018-10-19    218.837917
# 2018-10-22    218.378750
# 2018-10-23    218.074167
# 2018-10-24    218.139583
# 2018-10-25    217.571250
# 2018-10-26    216.398750
# 2018-10-29    215.150000
# 2018-10-30    214.056667
# 2018-10-31    213.017500
# 2018-11-01    211.981667
# 2018-11-02    210.471250
# Name: trend, dtype: float64
# ****************************************************************************************************************************************************************
# Seaonality : date1
# 2018-10-08   -0.767841
# 2018-10-09   -0.882809
# 2018-10-10   -0.541431
# 2018-10-11    0.378925
# 2018-10-12    0.629337
# 2018-10-15    0.900300
# 2018-10-16    0.967439
# 2018-10-17    0.726045
# 2018-10-18    2.176782
# ...

# %%
dataset.head()
# Out:
#              close    high     low    open    volume
# date1
# 2018-10-08  223.77  224.80  220.20  222.21  29663923
# 2018-10-09  226.87  227.27  222.25  223.64  26891029
# 2018-10-10  216.36  226.35  216.05  225.46  41990554
# 2018-10-11  214.45  219.50  212.32  214.52  53124392
# 2018-10-12  222.11  222.88  216.84  220.42  40337851

# %%
dataset = dataset[[ 'close']]

# %%
import statsmodels.api as sm
sm.stats.durbin_watson(dataset['close'])
# Out:
# 0.003218614241040646

# %%
#Typical Time Series problem

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(dataset['close'])
# Out:
# (-2.924256271358043,
#  0.04259916053208652,
#  0,
#  1256,
#  {'1%': -3.4355671297788666,
#   '5%': -2.8638438984080117,
#   '10%': -2.5679966213893057},
#  9504.204413624098)

# %%
def ad_check(tseries):
  print("*******Augmented Dickey Fuller Test - To check data is Stationary or Non-stationary*******")
  result=adfuller(tseries)
  labels=['ADF Stats Test','p-value','#Lags','No of Observation']
  for i,j in zip(result, labels):
    print(j+':'+str(i))
    if result[1]<=0.05:
       print("Strong evidence against null hypothesis and my timeseries is Stationary")
    else:
        print("Weak evidence against null hypothesis and my timeseries is Non-Stationary")

# %%
ad_check(dataset['close'])
# Out:
# *******Augmented Dickey Fuller Test - To check data is Stationary or Non-stationary*******
# ADF Stats Test:-2.924256271358043
# Strong evidence against null hypothesis and my timeseries is Stationary
# p-value:0.04259916053208652
# Strong evidence against null hypothesis and my timeseries is Stationary
# #Lags:0
# Strong evidence against null hypothesis and my timeseries is Stationary
# No of Observation:1256
# Strong evidence against null hypothesis and my timeseries is Stationary

# %%
dataset['seasonality']=dataset['close']-dataset['close'].shift(12)

# %%
dataset.head(15)
# Out:
#              close  seasonality
# date1
# 2018-10-08  223.77          NaN
# 2018-10-09  226.87          NaN
# 2018-10-10  216.36          NaN
# 2018-10-11  214.45          NaN
# 2018-10-12  222.11          NaN
# 2018-10-15  217.36          NaN
# 2018-10-16  222.15          NaN
# 2018-10-17  221.19          NaN
# 2018-10-18  216.02          NaN
# 2018-10-19  219.31          NaN
# 2018-10-22  220.65          NaN
# 2018-10-23  222.73          NaN
# 2018-10-24  215.09        -8.68
# 2018-10-25  219.80        -7.07
# 2018-10-26  216.30        -0.06

# %%
ad_check(dataset['seasonality'].dropna())
# Out:
# *******Augmented Dickey Fuller Test - To check data is Stationary or Non-stationary*******
# ADF Stats Test:-7.457943020993591
# Strong evidence against null hypothesis and my timeseries is Stationary
# p-value:5.449282442015127e-11
# Strong evidence against null hypothesis and my timeseries is Stationary
# #Lags:16
# Strong evidence against null hypothesis and my timeseries is Stationary
# No of Observation:1228
# Strong evidence against null hypothesis and my timeseries is Stationary

# %%
# My TimeSeries Trend and Seasonality both are Stationary now
# Trend : d = 0
# Seasonality : D = 1

# Parameters (k) = p d q
# p = partial autocorrelation or autoregressive method
# d = difference (lag function) or integrated method
# q = autocorrelation or moving avg method

# Trend :
# p = ?
# d = 0
# q = ?

# Seasonality
# P = ?
# D = 1
# Q = ?

# %%
# To find the P and Q value basis graph

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
# trend

# %%
plot_pacf(dataset['close'], lags=14)
plt.show()

# %%
plot_acf(dataset['close'], lags=70)
plt.show()

# %%
plot_pacf(dataset['seasonality'].dropna(), lags=14)
plt.show()

# %%
plot_acf(dataset['seasonality'].dropna(), lags=14)
plt.show()

# %%
# Trend :
## p = 1
## d = 0
## q = 60

# Seasonality
## P = 1
## D = 1
## Q = 9

# %%
# Building Time Series Forecasting Model
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(dataset['close'], order=(1,0,1), seasonal_order=(1,1,1,12))
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
result = model.fit()
print(result.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#                                      SARIMAX Results
# ...
# Dep. Variable:                              close   No. Observations:                 1257
# Model:             SARIMAX(1, 0, 1)x(1, 1, 1, 12)   Log Likelihood               -4813.954
# Date:                            Fri, 06 Oct 2023   AIC                           9637.907
# Time:                                    10:55:35   BIC                           9663.542
# Sample:                                         0   HQIC                          9647.546
#                                            - 1257
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import itertools

p = d = q = range(0,2)
pdq = list(itertools.product(p, d, q)) # trend
seasonal_pdq = [(x[0], x[1], x[2], 12 ) for x in pdq]

print("Few parameter combinations are :")
print('{} x {}'.format(pdq[1], seaonal_pdq[1]))
print('{} x {}'.format(pdq[2], seaonal_pdq[2]))
# Out:
# Few parameter combinations are :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa41b2707f35> in <cell line: 8>()
#       6
#       7 print("Few parameter combinations are :")
# ----> 8 print('{} x {}'.format(pdq[1], seaonal_pdq[1]))
#       9 print('{} x {}'.format(pdq[2], seaonal_pdq[2]))
#
# NameError: name 'seaonal_pdq' is not defined

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = sm.tsa.statespace.SARIMAX(dataset['Thousands of Passengers'], order=param,
                                 seasonal_order=param_seasonal, enforce_stationarity=False,
                                             enforce_invertibility=False)
            result = model.fit()
            print("ARIMA{}x{} - AIC:{}".format(param, param_seasonal, result.aic))
        except:
            continue
